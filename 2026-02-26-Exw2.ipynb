# %% [markdown]
# # Exercise 1- Micro 110

# %% [markdown]
# Note: empty markdown cells are for your responses.
#
# Note: a # symbol within the code indicates useful information for the code.
#
# Note: You are expected to enter information anywhere with a ###### symbol.

# %% [markdown]
# For this question, you are going to perform some analyses on the data from the "donut eating professor" problem introduced in class.
#
# Reference the course's Jupyter exercise to help you navigate the code

# %%
from statistics import mode

# The following are import functions.  You do not need to change them
import numpy as np
from scipy import stats
import scipy
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.ndimage import mean, median, variance
warnings.simplefilter('ignore', DeprecationWarning)

# %% [markdown]
# There are 12 professors at a hypothetical university.   Their weights are as follows:
#
# | Professor | Weight (kg) |
# |:--------:|:--------:|
# |  Schmuggles   |  75   |
# |  Bopsey   |  97   |
# |  Pallitto   |  86   |
# | Homer | 85 |
# | Schnickerson | 75 |
# | Levin | 67 |
# | Honkey-Doorey | 114 |
# | Zingers | 140 |
# | Boehmer | 69 |
# | Queenie | 60 |
# | Googles-Boop | 90 |
# | Calzone | 103 |
#
# (a) What are the mean, median, and mode of the weight in kg for this group of professors?

# %%
# The following code defines two arrays.  The first array lists the names of the professors.  The second array lists their weights, and is incomplete.   
# Complete the code for the second array.  Also add in the relevant code to print the mean, median, and mode
#####  Part a code below

professors = np.array(["Schmuggles", "Bopsey", "Pallitto", "Homer", "Schnickerson", "Levin", "Honkey-Doorey", "Zingers", "Boehmer", "Queenie", "Googles-Boop", "Calzone"])

# Complete the array below

weights = np.array([75, 97, 86, 85, 75, 67, 114, 140, 69, 60, 90, 103])

weights = weights.reshape(len(weights), 1) # Prepare the data for pandas
df = pd.DataFrame(data=weights, columns=['Weights']) # Transform data to pandas DataFrame
print('Data: \n', df)

# Add commands to print the mean, median, and mode below
print("Sample mean: ", mean(df))
print("Sample median: ", median(df))
print("Sample mode: ", mode(df))



#####
# Out:
# Data:
#      Weights
# 0        75
# 1        97
# 2        86
# 3        85
# 4        75
# 5        67
# 6       114
# 7       140
# 8        69
# 9        60
# 10       90
# 11      103
# Sample mean:  88.41666666666667
# Sample median:  85.5
# Sample mode:  Weights

# %% [markdown]
# (b) Generate a histogram of the weights

# %%
####### part b code below
import seaborn as sns
sns.set(color_codes=True)
plt.figure(dpi=300)

plt.hist(weights, bins=10)
plt.show()

#######
